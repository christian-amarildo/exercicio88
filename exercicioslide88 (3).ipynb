# %% [markdown]
# # exercícios do slide 88

# %% [markdown]
# ### questão 7

# %%
from IPython.display import Image
Image(filename=r'C:\Users\chris\Downloads\questao7.png')

# %% [markdown]
# barramento de dados:
#     O barramento de dados faz a ligação entre o registrador de dados da memória e a memória principal, para a tranferência de informações entre os dois.
#     Quanto a sua direção e fluxo, esse barramento admite o fluxo bidirecional, ou seja, ora os sinais percorrem do processador para a memória ora da memória para o processador
#
# barramento de endereços:
#     Interliga o registrador de endereços da memória à memória principal para a tranferência dos bits que representam um determinado endereço
#     É unidirecional, sendo apenas no sentido do processador para a memória principal
#
# barramento de controle:
#     Interliga o processador à memória principal para a passagem de sinais de controle durante uma operação de leitura ou escrita.
#     É bidirecional, pois o processador pode enviar sinais para a memória principal, e a memória pode enviar sinais para o processador do tipo "WAIT" por exemplo

# %% [markdown]
# ### questão 8

# %%
from IPython.display import Image
Image(filename=r'C:\Users\chris\Downloads\questão8.png')

# %% [markdown]
# 1:O processador envia um endereço para o registrador de endereçõs da memória.
#
# 2:O endereço é enviado pelo barramento de endereços até a memória
#
# 3:O processador envia um comando de leitura para o controlador de memória.
#
# 4:O endereço é decodificado e é localizado a célula correspondente na memoria
#
# 5:Os dados do endereço é enviado pelo barramento de dados ate o registrador de dados da memómia

# %% [markdown]
# ### questao 9

# %%
from IPython.display import Image
Image(filename=r'C:\Users\chris\Downloads\questão9.png')

# %% [markdown]
# 1:O processador envia um endereço para o registrador de endereçõs da memória.
#
# 2:O endereço é enviado pelo barramento de memória até a memória
#
# 3:O Processador coloca no registrador de dados da memória o dado a ser transferido
#
# 4:O processador aciona um comando de escrita pelo barramento de controle.
#
# 5:O dado é tranferido para a célula de memória pelo barramento de dados. podendo excluir os dados anteriores da célula em questão.

# %% [markdown]
# ### questão 13

# %%
from IPython.display import Image
Image(filename=r'C:\Users\chris\Downloads\questão13.png')

# %% [markdown]
# Como o armazenamento começou a partir da célula 27FA (hex) = 10234 (dec) e cada célula consegue suportar m caractere, então, a célula ue corresponde ao primeiro j se da por:
#
# 10234+128x9= 11.386 , ou então, 2c7a (hex)

# %% [markdown]
# ### questão 14

# %%
from IPython.display import Image
Image(filename=r'C:\Users\chris\Downloads\questão14.png')

# %% [markdown]
# Considerando as informações da questão podemos concluir que o DRAM será mais barato quando:
#
# 5 + 0.00001bits = 1 + 0.00002bits
# 4 + 0.00001bits = 0.00002bits
# 4 + 0.00001bits = 0.00002bits
# 4=0.00001bits
# 4/0.00001= bits
# bits= 400 000

# %% [markdown]
# ### questão 26

# %%
from IPython.display import Image
Image(filename=r'C:\Users\chris\Downloads\questão26.png')

# %%
from IPython.display import Image
Image(filename=r'C:\Users\chris\Downloads\decodificador .png')

# %%
from IPython.display import Image
Image(filename=r'C:\Users\chris\Downloads\decodificador imagem.png')
